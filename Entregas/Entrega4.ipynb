# %% [markdown]
# # Entrega 4: Sistemas lineales y valores propios
#
# **Departamento de Ciencias Físicas, Exactas & Energía / FIDCA**
#
# <!--
# Copyright © Angela Villota y Aníbal Sosa.
#
# El contenido textual está licenciado bajo Creative Commons
# Attribution-NonCommercial 4.0 International (CC BY-NC 4.0).
#
# El código y la lógica de los notebooks están licenciados bajo
# PolyForm Noncommercial License 1.0.0.
#
# Consulte el archivo LICENSE del repositorio para conocer los términos completos.
# -->

# %% [markdown]
# Para el sistema de ecuaciones diferenciales
#
# $$x^{\prime} = x + 3y +3z$$
# $$y^{\prime} = -3x -5y-3z$$
# $$z^{\prime} =3x + 3y + z$$
#
#
#
# 1. Escriba el sistema en forma matricial y determine la matriz del sistema.
# 2. Demuestre que el polinomio caracteristico de A es $p(\lambda)=(1-\lambda)(\lambda+2)^2$
# 3. Encuentre la solución general del sistema usando la rutina reef la cual escalona matrices (ver ejemplo en la siguiente celda de código).
# 4. Resuelva numéricamente este sistema de ecuaciones junto con las condiciones iniciales $x(0)=0$, $y(0)=-1$ y $z(0)=-1$ usando el método de euler.
# 5. Grafique cada solución en un plano de la forma V dependiente vs $t$
# 6. Usando las gráficas anteriores determine la estabilidad del equilibrio (Compruebe lo encontrado en la primera parte)
# 7. Grafique el espacio fase.
