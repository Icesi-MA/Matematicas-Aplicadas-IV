# %% [markdown]
# **Problema 1.**
#
#  If a nonlinear system depends on a parameter, then the equilibrium points can change
#  as the parameter varies. In other words, as the parameter changes, a bifurcation can
#  occur. Consider the one-parameter system family of systems
#
#  $$\dfrac{dx}{dt} = x^2 - a$$
#  $$\dfrac{dy}{dt} = -yx^2-y$$
#
#  where a is the parameter.
#
#  1. Show that the system has no equilibrium points if $a < 0$.
#  2. Show that the system has two equilibrium points if $a > 0$.
#  3. Show that the system has exactly one equilibrium point if $a = 0$.
#  4. Find the linearization of the equilibrium point for $a = 0$ and compute the
#  eigenvalues of this linear system. Is this point stable?

# %% [markdown]
# **Problema 2.**
#
# Encuentre todos los puntos críticos del sistema y clasifiquelos de acuerdo a su estabilidad (Todos los paasos deben aparecer en la solución presentada).
#
# $$ \dfrac{dx}{dt} = -8x^2 -6xy + 480x$$
#
# $$ \dfrac{dy}{dt} = -x^2y - y^3  + 2500y $$

# %% [markdown]
# **Problema 3.**
#
# Considere la siguiente ecuación diferencial
#
# $$\dfrac{d^2x}{dt^2}=-\dfrac{g}{2l}\sin{(2x)}$$
#
# 1. De una breve descripción de la situación que modela esta ecuación diferencial.
# 1. Utilice un cambio de variable para escribir la ecuación diferencial en forma de sistema. Qué tipo de sistema se tiene?
# 2. Si $g=32$ y $l=4$ encuentre todos los puntos críticos del sistema.
# 3. Utilice el método numérico usado en clase para determinar la estabilidad del punto crítico $(0,0)$ y los puntos críticos más cercanos al origen. Use gráficas adecuadas (en python) para responder esta pregunta.
# 4. Usando la parte anterior se puede concluir la estabilidad de los otros puntos críticos? Explique en detalle su respuesta.
