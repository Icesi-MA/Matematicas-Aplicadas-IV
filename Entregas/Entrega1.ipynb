# %% [markdown]
# # Entrega 1: Ecuaciones autónomas y separación de variables
#
# **Departamento de Ciencias Físicas, Exactas & Energía / FIDCA**
#
# <!--
# Copyright © Angela Villota y Aníbal Sosa.
#
# El contenido textual está licenciado bajo Creative Commons
# Attribution-NonCommercial 4.0 International (CC BY-NC 4.0).
#
# El código y la lógica de los notebooks están licenciados bajo
# PolyForm Noncommercial License 1.0.0.
#
# Consulte el archivo LICENSE del repositorio para conocer los términos completos.
# -->

# %% [markdown]
# **Problema 1:**
#
# Considere la ecuación diferencial
#
# $$ \dfrac{dx}{dt} = x^4 +4x^3 - 4x^2 - 16x. $$
#
# **a)** Utilice arreglos y gráficas en python para encontrar todas las soluciones de equilibrio.
#
# **b)** Use la o las gráficas de la parte a) para clasificar cada una de las soluciones de equilibrio encontradas justificando claramente su respuesta.
#
# **c)** Calcule el siguiente límite $$ \lim_{t\to\infty} x(t), $$
#  donde $x=x(t)$ es la solución del problema de valor inicial
#
#  $$\dfrac{dx}{dt} = x^4 +4x^3 - 4x^2 - 16x, \ \ \ \ x(20)=-5/2.$$

# %% [markdown]
# **Problema 2:**
#
# Resuelva la ecuación diferencial $$ \dfrac{dx}{dt} = 4 - x^2 $$ usando separación de variables, la solución debe estar en forma explícita.

# %% [markdown]
# **Problema 3:**
#
# Resuelva en detalle el problema 4 de la sección 1.1 del texto guía del curso.
