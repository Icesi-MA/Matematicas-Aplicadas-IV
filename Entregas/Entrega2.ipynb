# %% [markdown]
# # Entrega 2: Modelos y problemas de valor inicial
#
# **Departamento de Ciencias Físicas, Exactas & Energía / FIDCA**
#
# <!--
# Copyright © Angela Villota y Aníbal Sosa.
#
# El contenido textual está licenciado bajo Creative Commons
# Attribution-NonCommercial 4.0 International (CC BY-NC 4.0).
#
# El código y la lógica de los notebooks están licenciados bajo
# PolyForm Noncommercial License 1.0.0.
#
# Consulte el archivo LICENSE del repositorio para conocer los términos completos.
# -->

# %% [markdown]
# **Problema 1.**
#
# Considere la ecuación diferencial
#
# $$ \dfrac{dP}{dt} = 0.4P\Bigg(1-\dfrac{P}{230}\Bigg) $$
#
# 1. Usar alguno de los métodos analíticos estudiados en clase para encontrar la solución de la ecuación diferencial en forma explícita.
#
# 2. Use la parte 1 para resolver el p.v.i
# $$ \dfrac{dP}{dt} = 0.4P\Bigg(1-\dfrac{P}{230}\Bigg), \ \ \ \ P(0)=400. $$
#
# 3. Grafique en el mismo plano la solución exacta y numérica del p.v.i anterior en $[0,10]$ para los siguientes valores de $h$, a) $1$, b) $0.5$, c) $0.1$ y d) $0,001$
#
# 4. Use el método de Euler y algunas condiciones iniciales adecuadas para clasificar las soluciones de equilibrio de la ecuación diferencial.
#
# **Nota:  Se debe usar el método de Euler trabajado en clase.**

# %% [markdown]
# **Problema 2.**
#
# Considere la ecuación diferencial
#
# $$ \dfrac{dx}{dt} = ax + x^3 $$
#
# a) Encuentre la solución general si $a=0$.
#
# b) ¿Es $x(t)=0$ para todo $t \in \mathbb{R}$, una solución de esta ecuación diferencial?
#
# c) Determine todos los posibles valores de $a$ que hagan que esta ecuación diferencial tenga exactamente 3 soluciones de equilibrio.
#
# d) ¿Es posible que esta ecuación diferencial tenga exactamente 2 soluciones de equilibrio?
#
# e) Dibuje la línea de fase para el valor de $a=-9$. Determine los equibrios,
#  clasifiquelos y calcule $\displaystyle\lim_{t \to \infty}x(t)$ si se agrega la condición inicial $ x(2)=5
# $.
#
# f) Aplique el método de Euler para un valor de $h$ suficientemente pequeño, grafique su solución y compruebe la respuesta obtenida en la parte anterior.
#
# **Nota:  Se debe usar el método de Euler trabajado en clase.**

# %% [markdown]
# **Problema 3.**
#
# La siguiente tabla corresponde a una función $f(t)$ medida en centímetros por segundos para una cierta partícula que se mueve a lo largo del eje horizontal $t$
#
# |t|0|0.2|0.6|0.9|1|2|2.4|2.6|3|3.1|3.7|4|4.5|5|
# |-|-|-|-|-|-|-|-|-|-|-|-|-|-|-|
# |f(t)|2|3|-1.5|2|0.5|3|3.5|3.5|5|0|-1|1|3|4|
#
# Ahora considere el problema de valor inicial
#
# $$ \dfrac{dx}{dt} = f(t), \ \ \ x(0)=2. $$
#
# 1. Modifique la rutina para el método de Euler usada en clase y utilicela para aproximar la solución del p.v.i en el intervalo $[0,5]$.
#
# 2. Grafique la solución aproximada y dé una descripción del movimiento de la partícula. Explique claramente su respuesta.

# %% [markdown]
# **Problema 4.**
#
# A 5-gallon bucket is full of pure water. Suppose we begin dumping salt into the bucket at a rate of 1/4 pounds per minute. Also, we open the spigot so that 1/2 gallons per minute leaves the bucket, and we add pure water to keep the bucket full. If the salt water solution is always well mixed, what is the amount of salt in the bucket after
#
# 1.   1 minute?
# 2.   10 minutes?
# 3.   60 minutes?
# 4.   1000 minutes?
# 5.   a very, very long time?
