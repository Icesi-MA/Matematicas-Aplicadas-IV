# %% [markdown]
# # Problema
#
# Considere el sistema de ecuaciones diferenciales
#
# $$\dfrac{dx}{dt} =-6x $$
#
# $$\dfrac{dy}{dt} = x+y$$
#
# $$\dfrac{dz}{dt} = y+z$$
#
#
#
# 1. Encuentre por ensayo y error una solución no nula del sistema.
#
# 2. Modifique el método de Euler trabajado en clase para aproximar la solución del problema de valor inicial
#
# $$\dfrac{dx}{dt} =-6x, \ \ \ \ \ \ \ \ \ \ x(0)=1 $$
#
# $$\dfrac{dy}{dt} = x+y, \ \ \ \ y(0)=1$$
#
# $$\dfrac{dz}{dt} = y+z, \ \ \ \ \ \ z(0)=-2$$
#
# 3. Realizar las gráficas en python de cada una de las componentes en planos de la forma var dep vs var ind.
#
# 4. Grafique el espacio fase.
