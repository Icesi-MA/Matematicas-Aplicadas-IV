# %% [markdown]
# # Entrega 9: Sistemas disipativos
#
# **Departamento de Ciencias Físicas, Exactas & Energía / FIDCA**
#
# <!--
# Copyright © Angela Villota y Aníbal Sosa.
#
# El contenido textual está licenciado bajo Creative Commons
# Attribution-NonCommercial 4.0 International (CC BY-NC 4.0).
#
# El código y la lógica de los notebooks están licenciados bajo
# PolyForm Noncommercial License 1.0.0.
#
# Consulte el archivo LICENSE del repositorio para conocer los términos completos.
# -->

# %% [markdown]
# A continuación se le pide responder por grupo las siguientes preguntas, utilizando una copia del presente cuaderno para consignar todas sus respuestas con el formato requerido.
#
# **Usted debe considerar las sección 5.4 del texto de Blanchard et al (2012), trabajar en los problemas del cuaderno entregar a mas tardar el martes 29 de octubre.**
#
# **<u>Preguntas</u>**
#
# A continuación encuentra separadas por celda cada pregunta, así usted solo debe continuar escribiendo en la celda para dar cada respuesta. No olvide que todas sus respuestas deben ir acompañadas de al menos un argumento geométrico o numérico y uno algebráico o en lenguaje natural.

# %% [markdown]
# 1.   (10 pts) (a) For the slightly damped pendulum ($b > 0$ but $b$ close to zero), find the set of
# all initial conditions $(θ(0), v(0))$ that execute exactly two complete revolutions for $t > 0$ (that is, pass the vertical position exactly twice) before settling into
# a back-and-forth swinging motion. Sketch the phase portrait for the slightly damped pendulum and shade these initial conditions.
#
# (b) Repeat part (a) for solutions that execute exactly five complete revolutions for $t > 0$ before settling into back-and-forth swinging motion.

# %% [markdown]
# 2. (15 pts)  Suppose that rather than adding damping to the ideal pendulum, we add a small
# amount of “antidamping”; that is, we take b slightly negative in the damped pendulum system. Physically this would mean that whenever the velocity is nonzero, the pendulum is accelerated in the direction of motion.
#
# (a) Linearize and classify the equilibrium points in this situation.
#
# (b) Sketch the phase portrait for this system.
#
# (c) Describe in a brief paragraph the behavior of a solution with initial condition near $θ = v = 0$.

# %% [markdown]
# 3.   (20 pts)  Suppose the smell of a bunch of dead fish in the region $−2 ≤ x ≤ 2$, $−2 ≤ y ≤ 2$ is given by the function
# $$S(x, y) = x^2 + y^2 − \frac{x^4 + y^4}{4}
# − 3x^2 y^2 + 100.$$
#
# (a) What is the gradient system whose vector field is the gradient of $S$?
#
# (b) Using an applet  to sketch the phase portrait for this system, and draw in the same plot the numerical solution of the gradient system for four different initial conditions in each quadrant.
#
# (c) How many dead fish are there, and where are they?
#
# (d) Using the results from part (b), sketch in the same applet the level sets of $S$.
#
# (e) Why would the model not be realistic for large values of x or y?

# %% [markdown]
# 4. (5 pts) The following phase portrait cannot occur for a gradient system. Why not?

# %%
from pathlib import Path
from IPython.display import Image, display

image_path = Path('../_static/phasepor.jpg')
print('Tomado de Blanchard (2011)')
if image_path.exists():
    display(Image(filename=str(image_path)))
else:
    print('Imagen opcional no disponible: agregue _static/phasepor.jpg para visualizarla.')

# %% [markdown]
# **La entrega solo se acepta en el formato de un cuaderno python colab .**
