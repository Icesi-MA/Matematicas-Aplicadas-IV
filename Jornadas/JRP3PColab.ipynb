# %% [markdown]
# <img src=http://www.acofi.edu.co/eiei2016/wp-content/uploads/2016/09/Logo-Universidad-ICESI.jpg width="300" height="200" align="center">
#
# #**<big><big>Matemáticas Aplicadas IV</big></big><br><small>Depto. Ciencias Físicas y Exactas / Facultad de Ingeniería</small><br><small>_*Tercera Jornada de Resolucion de Problemas*_ (Sistemas de Ecuaciones, Sistemas de ecuaciones diferenciales no lineales, Equilibrios, Linealización, Estabilidad de equilibrios). </small>**
#
# **Descripción de la jornada**:
#
# En esta jornada usted va a encontrar un problema que se puede resolver con la teoría estudiada en clase y su solución debe ser entregada en un cuaderno colab con la solución detallada de este problema. Cada problema debe ser abordado en forma individual utilizando todos los recursos que usted disponga. La idea central es que elabore sus respuestas o construcciones siguiendo los lineamientos dados a continuación:
#
# 1. Escriba con claridad sus propias ideas.
#
# 2. Argumente usando lenguaje propio de las matemáticas: geométrico o algebraico, según sea el caso, cada una de sus respuestas.
#
# 3. Respalde, cuando lo considere conveniente, sus argumentos geométricos y algebraicos con imágenes o applets diseñadas en GeoGebra o librerias de Python.
#
# 4.	Resuelva los problemas de manera autónoma; describiendo las estrategias usadas para “atacar” el problema, poniendo a prueba sus soluciones y en lo posible planteando nuevos e “interesantes” interrogantes asociados al problema formulado. Si utiliza un resultado o teorema, este debe ser debidamente citado y si es un resultado ajeno a los estudiados en el curso o del texto guía debe proveer la respectiva demostración.
#
# 5. El cuaderno solución (como archivo ipynb) de esta jornada debe ser guardado (no compartido) en la carpeta con título "Entrega J Solucion problemas 3" que se encuentra en la carpeta del curso. El titulo debe tener el nombre del estudiante y el código.
#
# 6. **NO** se aceptará ningún archivo después de la hora de finalización de la clase.
#
# 7. Solamente se tiene acceso a los cuadernos colab del curso, sus cuadernos colab y Geogebra. Cualquier otra pestaña abierta diferente a las anteriores será considerada como fraude.

# %% [markdown]
# #Problema
#
# Considere la ecuación diferencial
#
# $$\dfrac{d^2x}{dt^2} + ax - x^3 = 0$$
#
# donde $a$ es un parámetro real.
#
# 1.   Escriba la ecuación diferencial como un sistema de ecuaciones de primer orden.
# 2.   Determine todos los valores de $a$ que hagan que el sistema tenga exactamente 3 puntos críticos.
# 3. Determine todos los puntos críticos del sistema si $a=9$, linealice el sistema en torno a cada punto crítico y haga un análisis de estabilidad para cada punto crítico.
# 4. Use el método de Euler trabajado en clase para resolver numéricamente el sistema para el valor de $a=9$ y compruebe lo encontrado en la pregunta anterior usando gráficas de las listas o variables encontradas al resolver numéricamente el sistema.
