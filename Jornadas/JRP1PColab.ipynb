# %% [markdown]
# # Primera jornada de resolución de problemas
#
# **Departamento de Ciencias Físicas, Exactas & Energía / FIDCA**
#
# <!--
# Copyright © Angela Villota y Aníbal Sosa.
#
# El contenido textual está licenciado bajo Creative Commons
# Attribution-NonCommercial 4.0 International (CC BY-NC 4.0).
#
# El código y la lógica de los notebooks están licenciados bajo
# PolyForm Noncommercial License 1.0.0.
#
# Consulte el archivo LICENSE del repositorio para conocer los términos completos.
# -->

# %% [markdown]
# **Descripción de la jornada**:
#
# En esta jornada usted va a encontrar 2 problemas que se pueden resolver con la teoría estudiada en clase y debe entregar en un cuaderno colab la solución de estos 2 problemas. Cada problema puede ser abordado en forma individual utilizando todos los recursos que usted disponga. La idea central es que elabore sus respuestas o construcciones siguiendo los lineamientos dados a continuación:
#
# 1. Escriba con claridad sus propias ideas.
#
# 2. Argumente usando lenguaje propio de las matemáticas: geométrico o algebraico, según sea el caso, cada una de sus respuestas.
#
# 3. Respalde, cuando lo considere conveniente, sus argumentos geométricos y algebraicos con imágenes o applets diseñadas en GeoGebra o librerias de Python.
#
# 4.	Resuelvan los problemas de manera autónoma; describiendo las estrategias usadas para “atacar” el problema, poniendo a prueba sus soluciones y en lo posible planteando nuevos e “interesantes” interrogantes asociados al problema formulado. Si utiliza un resultado o teorema, este debe ser debidamente citado y si es un resultado ajeno a los estudiados en el curso o del texto guía debe proveer la respectiva demostración.
#
# 5. El cuaderno solución (como archivo ipynb) de esta jornada debe ser guardado (no compartido) en la carpeta con título "Entrega J Solucion problemas 1" que se encuentra en la carpeta del curso. El titulo debe tener el nombre del estudiante y el código.
#
# 6. **NO** se aceptará ningún archivo después de la hora de finalización de la clase.
#
# 7. Solamente se tiene acceso a los cuadernos colab del curso, sus cuadernos colab y Geogebra. Cualquier otra pestaña abierta diferente a las anteriores será considerada como fraude.
#
# 8. Nivel uso IA: 0

# %% [markdown]
# **Problema 1.**
#
# **25 pts**
#
# Considere la ecuación diferencial
#
# $$ \dfrac{dy}{dx} = 32y + 8y^2 - 8y^3-2y^4. $$
#
# **a)** Utilice arreglos en **python** para graficar la función $f(y)$.
#
# **b)** Basado en la parte a) determine todas las soluciones de equilibrio de la ecuación diferencial dada y clasifique cada una de las soluciones de equilibrio encontradas justificando claramente su respuesta.
#
# **c)** Calcule el siguiente límite $$ \lim_{x\to\infty} y(x), $$
#  donde $y=y(x)$ es la solución del problema de valor inicial
#
#  $$\dfrac{dy}{dx} = 32y + 8y^2 - 8y^3-2y^4, \ \ \ \ y(\sqrt{2})=y_0.$$
#
# **NOTA:**
#
# No se está pidiendo solucionar la ecuación diferencial.

# %% [markdown]
# **Problema 2.**
#
# **25 pts**
#
# Un tanque de 150 galones contiene inicialmente 90 libras de sal disueltas en 90 galones de agua. Salmuera que contiene $2$ lb/gal de sal fluye hacia adentro del tanque a razón de $4$ gal/min, y la mezcla homogénea fluye hacia fuera del tanque a una razón de $3$ gal/min. Plantee un problema de valor inicial que modele la situación. Use el método de Euler con $h = 0.2$ para resolver numericamente el problema de valor inicial planteado y determine la cantidad de sal en el tanque $10.5$ minutos después del tiempo inicial. Use la línea de fase para la ecuación diferencial planteada para determinar que sucede con la cantidad de sal en el tanque a largo plazo.
#
# **NOTA:** Grafique la solución encontrada usando python.
