# %% [markdown]
# # Segunda jornada de resolución de problemas
#
# **Departamento de Ciencias Físicas, Exactas & Energía / FIDCA**
#
# <!--
# Copyright © Angela Villota y Aníbal Sosa.
#
# El contenido textual está licenciado bajo Creative Commons
# Attribution-NonCommercial 4.0 International (CC BY-NC 4.0).
#
# El código y la lógica de los notebooks están licenciados bajo
# PolyForm Noncommercial License 1.0.0.
#
# Consulte el archivo LICENSE del repositorio para conocer los términos completos.
# -->

# %% [markdown]
# **Descripción de la jornada**:
#
# En esta jornada usted va a encontrar un problema que se puede resolver con la teoría estudiada en clase y debe entregar en un cuaderno colab con la solución de este problema en detalle. El problema debe ser abordado en forma individual utilizando todos los recursos que usted disponga. La idea central es que elabore sus respuestas o construcciones siguiendo los lineamientos dados a continuación:
#
# 1. Escriba con claridad sus propias ideas.
#
# 2. Argumente usando lenguaje propio de las matemáticas: geométrico o algebraico, según sea el caso, cada una de sus respuestas.
#
# 3. Respalde, cuando lo considere conveniente, sus argumentos geométricos y algebraicos con imágenes o applets diseñadas en GeoGebra o librerias de Python.
#
# 4.	Resuelvan los problemas de manera autónoma; describiendo las estrategias usadas para “atacar” el problema, poniendo a prueba sus soluciones y en lo posible planteando nuevos e “interesantes” interrogantes asociados al problema formulado. Si utiliza un resultado o teorema, este debe ser debidamente citado y si es un resultado ajeno a los estudiados en el curso o del texto guía debe proveer la respectiva demostración.
#
# 5. El cuaderno solución (como archivo ipynb) de esta jornada debe ser guardado o cargado (no compartido) en la carpeta con título "Entrega Segunda Jornada Parte Colab" que se encuentra en el drive del curso. El titulo debe tener el nombre del estudiante y el código.
#
# 6. **NO** se aceptará ningún archivo después de la hora de finalización de la clase.
#
# 7. Solamente se tiene acceso a los cuadernos colab del curso, sus cuadernos colab y Geogebra. Cualquier otra pestaña abierta diferente a las anteriores será considerada como fraude.

# %% [markdown]
# **Problema**
#
# Para el sistema de ecuaciones diferenciales
#
# $$ \dfrac{dx}{dt} = 2y - 2x$$
# $$ \dfrac{dy}{dt} = -\dfrac{3}{4}x - \dfrac{3}{4}z$$
# $$ \dfrac{dz}{dt} = kx$$
#
# 1. Encuentre el polinomio característico de la matriz asociada al sistema para el valor de $k=1$, grafique el polinomio y obtenga una aproximación de uno de los valores propios, que se puede concluir acerca de los otros valores propios?.
#
# 2. Use el método de Euler (El usado en clase) para resolver el sistema dado con condiciones inciales $x(0)=-2$, $y(0)=-1$ y $z(0)=-1$ en el intervalo $[0,6\pi]$ para el valor de $k=1$ y Grafique cada solución en un plano de la forma variable dependiente vs variable independiente, que podemos concluir acerca del equilibrio $(0,0,0)$?.
#
# 3. Grafique el espacio fase y en este el punto inicial.
#
# 4. Use el método de Euler (El usado en clase) para resolver el sistema para $k= -1, 2/3, 2, 5$, grafique las soluciones (var dependiente vs v independiente) para cada valor de $k$ (una gráfica por sistema, es decir para cada valor de $k$) y determine que sucede con la estabilidad del origen en cada caso.
