# %% [markdown]
# # Proyecto final: métodos y sistemas de ecuaciones diferenciales
#
# **Departamento de Ciencias Físicas, Exactas & Energía / FIDCA**
#
# <!--
# Copyright © Angela Villota y Aníbal Sosa.
#
# El contenido textual está licenciado bajo Creative Commons
# Attribution-NonCommercial 4.0 International (CC BY-NC 4.0).
#
# El código y la lógica de los notebooks están licenciados bajo
# PolyForm Noncommercial License 1.0.0.
#
# Consulte el archivo LICENSE del repositorio para conocer los términos completos.
# -->

# %% [markdown]
# ## Proyectos / Problemas sustentación Semana 16
#
# Cada grupo de estudiantes debe investigar y/o consultar todos los temas que aparecen a continuación y presentar un cuaderno colab con la investigación realizada con todo detalle, formulación matemática, que tipo de problema resuelven, todo esto en el marco de los temas estudiados en el curso, después de la investigación los estudiantes deben estar en capacidad de sustentar lo investigado y poder resolver problemas con la teoría investigada, junto a cada problema se presentan algunos problemas que se pueden y deben resolver con esta teoría, incluya gráficos, rutinas en python para complementar el trabajo presentado.

# %% [markdown]
# ## 1. Método numérico RK
#
# Investigar el método Runge-Kutta de segundo orden para resolver numéricamente problemas de valor inicial de primer orden y como se aplicaría a los sistemas de primer orden. Comparar con diferentes sistemas de primer orden, los errores generados por el método de Euler y RK.

# %% [markdown]
# ## 2. Coeficientes indeterminados para sistemas
#
# Investigar el método de los coeficientes indeterminados para sistemas de ecuaciones diferenciales de primer orden no homogeneos, es decir, sistemas que se pueden escribir de la forma
#
# $$ X^{\prime} = AX + b(t) $$
#
# donde $b(t) \neq 0 \in \mathbb{R}^n$ y resuelva lo siguiente:
#
# 1. $$ dx/dt= 2x+3y-7 \\ \\ dy/dt = -x-2y+5 $$
#
# 2. $$ \begin{bmatrix}x\\y\end{bmatrix}^{\prime} = \begin{bmatrix}1 & -4\\ 4 & 1\end{bmatrix}\begin{bmatrix}x\\y\end{bmatrix} + \begin{bmatrix}4t+9e^{6t}\\-t+e^{6t}\end{bmatrix}$$
#
# 3. Una masa de 16 libras estira un resorte $8/3$ de pie. La masa
# inicialmente es liberada del reposo desde un punto ubicado
# $2$ pies por debajo de la posición de equilibrio, y el movimiento siguiente se desarrolla en un medio que
# ofrece una fuerza amortiguadora numéricamente igual
# a $1/2$ de la velocidad instantánea. Encuentre la ecuación de movimiento si la masa es conducida por una fuerza externa igual a $f(t)=10\cos{ 3t}$

# %% [markdown]
# ## 3. Exponencial de una matriz $ 2 \times 2$
#
# Investigar como se calcula la exponencial de una matriz $A$ de tamaño $2 \times 2$, es decir $e^{At}$ y como se aplica este concepto a la solución de sistemas de primer orden. Comparar con el método estudiado en clase.
